# %%
import pandas as pd
df=pd.read_csv('WorldCupMatches.csv')
df1=pd.read_csv('WorldCups.csv')

# %%
df.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
df1.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
x1=df1.Year
y1=df1.Attendance


plt.plot(x1,y1,label='First Plot',color='red')
#plt.plot(x2,y2,label='Second Plot')
plt.xlim(1930,2014)
plt.title('Year-Attendance Graph')
plt.xlabel('Year')
plt.ylabel('Attendance')

plt.legend()
plt.show()

# %% [markdown]
# # As it is clear from the above Data that first FIFA World Cup match was played om 1984 and after every 4 year it takes place.

# %% [markdown]
# # The above Graph shows the relationship between the Attendance i.e. Number of people went to watch the Match in Stadium and in which year they attended

# %% [markdown]
# # x axis shows the FIFA year and y-axis shows the attendance of the people who visited

# %%
df1.T
# Out:
#                         0               1        2          3            4   \
# Year                  1930            1934     1938       1950         1954
# Country            Uruguay           Italy   France     Brazil  Switzerland
# Winner             Uruguay           Italy    Italy    Uruguay   Germany FR
# Runners-Up       Argentina  Czechoslovakia  Hungary     Brazil      Hungary
# Third                  USA         Germany   Brazil     Sweden      Austria
# Fourth          Yugoslavia         Austria   Sweden      Spain      Uruguay
# GoalsScored             70              70       84         88          140
# QualifiedTeams          13              16       15         13           16
# MatchesPlayed           18              17       18         22           26
# Attendance         590.549         363.000  375.700  1.045.246      768.607
#
#                         5               6             7           8   \
# ...

# %%
df1['Year'].describe()
# Out:
# count      20.000000
# mean     1974.800000
# std        25.582889
# min      1930.000000
# 25%      1957.000000
# 50%      1976.000000
# 75%      1995.000000
# max      2014.000000
# Name: Year, dtype: float64

# %%
df1.shape
# Out:
# (20, 10)

# %%
df1.describe(include='all')
# Out:
#                Year Country  Winner  Runners-Up    Third   Fourth  \
# count     20.000000      20      20          20       20       20
# unique          NaN      15       9          10       14       16
# top             NaN  France  Brazil  Germany FR  Germany  Uruguay
# freq            NaN       2       5           3        3        3
# mean    1974.800000     NaN     NaN         NaN      NaN      NaN
# std       25.582889     NaN     NaN         NaN      NaN      NaN
# min     1930.000000     NaN     NaN         NaN      NaN      NaN
# 25%     1957.000000     NaN     NaN         NaN      NaN      NaN
# 50%     1976.000000     NaN     NaN         NaN      NaN      NaN
# 75%     1995.000000     NaN     NaN         NaN      NaN      NaN
# max     2014.000000     NaN     NaN         NaN      NaN      NaN
#
#         GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# count     20.000000       20.000000      20.000000         20
# ...

# %%
plt.xlim(1930,2014)
xticks=[1930,4,2014]

sns.stripplot(x='Year', y='Winner', data=df1, jitter=True)

# %% [markdown]
# # The above representation shows that in which FIFA world cup which Team had won the FIFA World Cup . Analysing that Graph and it is clear that First FIFa Cup was won by Uruguay Last 2014 FIFA Cup was won by Germany

# %%
xticks=[0,7,7] 
sns.countplot(y='Winner',data=df1,palette="Greens_d")

# %% [markdown]
# # The above representation tells us about the Teams who had won the FIFA world Cup atleast Once.
